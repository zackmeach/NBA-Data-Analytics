# %%
import nba_api
import pandas as pd
import warnings
from tqdm import tqdm
from time import sleep

warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# %%
logs = pd.read_csv('game_logs.csv').drop(columns='Unnamed: 0')
logs.head()
# Out:
#   SEASON_YEAR   GAME_ID            GAME_DATE      MATCHUP   MIN  TEAM_ID_(H)  \
# 0     2015-16  21501221  2016-04-13T00:00:00  WAS vs. ATL  48.0   1610612764
# 1     2015-16  21501227  2016-04-13T00:00:00  GSW vs. MEM  48.0   1610612744
# 2     2015-16  21501223  2016-04-13T00:00:00  DAL vs. SAS  48.0   1610612742
# 3     2015-16  21501222  2016-04-13T00:00:00  CHI vs. PHI  48.0   1610612741
# 4     2015-16  21501217  2016-04-13T00:00:00  BOS vs. MIA  48.0   1610612738
#
#   TEAM_ABBREVIATION_(H)          TEAM_NAME_(H) WL_(H)  FGM_(H)  FGA_(H)  \
# 0                   WAS     Washington Wizards      W       42       88
# 1                   GSW  Golden State Warriors      W       46       87
# 2                   DAL       Dallas Mavericks      L       31       77
# 3                   CHI          Chicago Bulls      W       39       83
# 4                   BOS         Boston Celtics      W       37       86
#
# ...
